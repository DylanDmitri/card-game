# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

text = """
Simple Strike
	melee attack
		+1 vs defense, lethal
	distract 2
	run 3
	"""

rcParams['text.usetex'] = True

txte = r"sample"

plt.text(5.0, 5.0, txte, fontsize=14)
ax = plt.gca()
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

plt.show()
